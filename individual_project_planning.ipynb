# %%
# Load the tidyverse package and read the players data set.
library(tidyverse)
players <- read_csv("data/players.csv")
players
# Out:
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.4     ✔ readr     2.1.5
# ✔ forcats   1.0.0     ✔ stringr   1.5.1
# ✔ ggplot2   3.5.1     ✔ tibble    3.2.1
# ✔ lubridate 1.9.3     ✔ tidyr     1.3.1
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Rows: 196 Columns: 7
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (4): experience, hashedEmail, name, gender
# dbl (2): played_hours, Age
# lgl (1): subscribe
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#     experience subscribe
# 1   Pro         TRUE
# 2   Veteran     TRUE
# ...

# %%
# Find the number of observations in the players data set.
count(players)
# Out:
#   n
# 1 196

# %%
# Produce summary statistics by finding the number of players in each level of gaming experience.
players_experience <- players |>
    group_by(experience) |>
    count()
players_experience
# Out:
#   experience n
# 1 Amateur    63
# 2 Beginner   35
# 3 Pro        14
# 4 Regular    36
# 5 Veteran    48

# %%
# Produce summary statistics by finding the proportion of players subscribed and unsubscribed to the game-related newsletter.
players_subscribe <- players |>
    group_by(subscribe) |>
    count()
players_subscribe
# Out:
#   subscribe n
# 1 FALSE      52
# 2  TRUE     144

# %%
# Produce summary statistics by determining if any emails are identical.
players_email <- players |>
    group_by(hashedEmail) |>
    count()
players_email
# Out:
#     hashedEmail                                                      n
# 1   0088b5e134c3f0498a18c7ea6b8d77b4b0ff1636fc93355ccc95b45423367832 1
# 2   055d1a2002f6308a95b03b8d17af28f43e9f91ca8b1e1fc439bf4d08b22e7c0f 1
# 3   060aca80f8cfbf1c91553a72f4d5ec8034764b05ab59fe8e1cf0eee9a7b67967 1
# 4   0ce7bfa910d47fc91f21a7b3acd8f33bde6db57912ce0290fa0437ce0b97f387 1
# 5   0d4d71be33e2bc7266ee4983002bd930f69d304288a8663529c875f40f1750f3 1
# 6   0d70dd9cac34d646c810b1846fe6a85b9e288a76f5dcab9c1ff1a0e7ca200b3a 1
# 7   11006065e9412650e99eea4a4aaaf0399bc338006f85e80cc82d18b49f0e2aa4 1
# 8   119f01b9877fc5ea0073d05602a353b91c4b48e4cf02f42bb8d661b46a34b760 1
# 9   11bf6125c4264b3a8f3bffa57b33bd598e2ea1ecd6331ad3bc54aa88e22db035 1
# 10  126ec350278422ba60ad575d230c19522fd568094b7c0fc17f8cc27fa4c810ab 1
# 11  1683a3e0aed65119f83540274ff6f965fdf66890613a80f88572dfb1d9f1d2ad 1
# 12  171d3c323c6430ffe0722c931f4cced5c48935f6804e0ff250964e4c41da55b1 1
# ...

# %%
# Calculate summary statistics by finding the average hours played by the players.
players_avg_hours <- players |>
    summarize(played_hours = mean(played_hours, na.rm = TRUE))
players_avg_hours

players_max_hours <- players |>
    summarize(played_hours = max(played_hours, na.rm = TRUE))
players_max_hours

players_min_hours <- players |>
    summarize(played_hours = min(played_hours, na.rm = TRUE))
players_min_hours
# Out:
#   played_hours
# 1 5.845918
#   played_hours
# 1 223.1
#   played_hours
# 1 0

# %%
# Produce summary statistics by determining the occurence of each name.
players_name <- players |>
    group_by(name) |>
    count()
players_name
# Out:
#     name      n
# 1   Aarav     1
# 2   Aaron     1
# 3   Adrian    1
# 4   Ahmed     1
# 5   Aiden     1
# 6   Akio      1
# 7   Akira     1
# 8   Alaric    1
# 9   Alex      1
# 10  Amelia    1
# 11  Amelie    1
# 12  Anastasia 1
# 13  Andy      1
# 14  Arash     1
# 15  Aria      1
# 16  Ariana    1
# 17  Arlo      1
# 18  Asher     1
# 19  Atlas     1
# 20  Aurora    1
# 21  Ayman     1
# 22  Bailey    1
# 23  Balthazar 1
# 24  Bella     1
# 25  Bianca    1
# 26  Bijan     1
# 27  Blake     1
# 28  Bodhi     1
# 29  Caden     1
# 30  Callum    1
# ⋮   ⋮         ⋮
# 167 Sidney    1
# 168 Sophia    1
# 169 Soren     1
# 170 Suki      1
# 171 Taylor    1
# 172 Thatcher  1
# 173 Théo      1
# 174 Tristan   1
# 175 Umar      1
# 176 Vasco     1
# 177 Vaughn    1
# 178 Violet    1
# 179 Vivian    1
# 180 Vivienne  1
# 181 Will      1
# 182 Willem    1
# 183 Winslow   1
# 184 Winston   1
# 185 Wren      1
# 186 Xander    1
# 187 Xenos     1
# 188 Xia       1
# 189 Yosef     1
# ...

# %%
# Produce summary statistics by finding the genders present in the players data set.
players_gender <- players |>
    group_by(gender) |>
    count()
players_gender
# Out:
#   gender            n
# 1 Agender             2
# 2 Female             37
# 3 Male              124
# 4 Non-binary         15
# 5 Other               1
# 6 Prefer not to say  11
# 7 Two-Spirited        6

# %%
# Calculate summary statistics by finding the average age of players in the data set.
players_age <- players |>
    summarize(Age = mean(Age, na.rm = TRUE))
players_age

players_max_age <- players |>
    summarize(Age = max(Age, na.rm = TRUE))
players_max_age

players_min_age <- players |>
    summarize(Age = min(Age, na.rm = TRUE))
players_min_age
# Out:
#   Age
# 1 21.13918
#   Age
# 1 58
#   Age
# 1 9

# %%
# The same data can be gathered by using summary to find statistics on the players data set.
summary(players)
# Out:
#   experience        subscribe       hashedEmail         played_hours
#  Length:196         Mode :logical   Length:196         Min.   :  0.000
#  Class :character   FALSE:52        Class :character   1st Qu.:  0.000
#  Mode  :character   TRUE :144       Mode  :character   Median :  0.100
#                                                        Mean   :  5.846
#                                                        3rd Qu.:  0.600
#                                                        Max.   :223.100
#
#      name              gender               Age
#  Length:196         Length:196         Min.   : 9.00
#  Class :character   Class :character   1st Qu.:17.00
#  Mode  :character   Mode  :character   Median :19.00
#                                        Mean   :21.14
#                                        3rd Qu.:22.75
#                                        Max.   :58.00
#                                        NA's   :2

# %% [markdown]
# # Data Description
# The data presented was collected by a research group in computer science at UBC led by Frank Wood, used to predict usage of a Minecraft server by gathering data on the players and sessions involved. This project aims to curate recruitment efforts and ensure ample resources for the attracted players.

# %% [markdown]
# ### Players Data Set
# The players data set includes a list of all unique players with data about each player. After reading the data set, I am able
# to identify that there are 7 variables and 196 observations. There are a variety of data types, including character, logical and double.
# - experience(chr): the level of experience of a player, includes amateur, beginner, regular, veteran, and pro
# - subscribe(lgl): the status of subscription to the game-related newsletter, TRUE for subscribed and FALSE for unsubscribed
# - hashedEmail(chr): an encrypted version of an email address used to protect the user's personal information, for identification
# - played_hours(dbl): the number of hours played on Minecraft
# - name(chr): the player's name
# - gender(chr): the player's gender
# - Age(dbl): the player's age
#
# **Experience Levels**
#
# The table shows that nearly a third of the players are classified as amateur and the least number of players are considered pro level.
# | Experience | Count |
# | ---------- | ----- |
# | Amateur    | 63    |
# | Beginner   | 35    |
# | Regular    | 36    |
# | Veteran    | 48    |
# | Pro        | 14    |
#
# **Subscription Status**
#
# About 73% of players are subscribed to the Minecraft newsletter.
# | Subscribe | Count |
# | --------- | ----- |
# | FALSE     | 52    |
# | TRUE      | 144   |
#
# **Hashed Email**
#
# Since a hashed email is a one-way encrypted version of an email address, converted to protect the user's personal information, each player has a unique code (no repeats). Thus, this might be used instead to identify players instead of numbering them 1 through 196.
#
# **Hours**
#
# The average hours played by the users in the data set is 5.85 hours, with a maximum of 223.1 hours and a minimum of 0 hours.
# | Average Hours | Max Hours | Min Hours |
# | ------------- | --------- | --------- |
# | 5.85          | 233.1     | 0         |
#
# **Name**
#
# Similar to the hashedEmail variable, the player's names can be used as identification since each is unique to the player with no repeats.
#
# **Gender**
#
# As provided in the table below, majority of players are male with some females. A smaller number of people are agender, two-spirited, and non-binary.
# | Gender            | Count |
# | ----------------- | ----- |
# | Agender           | 2     |
# | Female            | 37    |
# | Male              | 124   |
# | Non-binary        | 15    |
# | Other             | 1     |
# | Prefer not to say | 11    |
# | Two-spirited      | 6     |
#
# **Age**
#
# The average age of players in the data set is 21.14 years old, with a maximum age of 58 and a minimum age of 9.
# | Average Age   | Max Age | Min Age |
# | ------------- | ------- | ------- |
# | 21.14         | 58      | 9       |

# %% [markdown]
# From calculating summary statistics and reading the data set, I noticed issues such as the use of other and prefer not to say in the gender variable which can provide inaccuracies during analysis since some players did not explicitly list their gender. Additionally, the length of hashedEmail is difficult for the use of identification. Furthermore, from just looking at the data set, I am unable to determine the accuracy of classification regarding experience level and whether their method was effective. Also, the expression of time played in hours is not as accurate as it could be by using minutes instead.

# %%
# Read the sessions data set.
sessions <- read_csv("data/sessions.csv")
sessions
# Out:
# Rows: 1535 Columns: 5
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (3): hashedEmail, start_time, end_time
# dbl (2): original_start_time, original_end_time
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#      hashedEmail
# 1    bfce39c89d6549f2bb94d8064d3ce69dc3d7e72b38f431d8aa0c4bf95ccee6bf
# 2    36d9cbb4c6bc0c1a6911436d2da0d09ec625e43e6552f575d4acc9cf487c4686
# 3    f8f5477f5a2e53616ae37421b1c660b971192bd8ff77e3398304c7ae42581fdc
# 4    bfce39c89d6549f2bb94d8064d3ce69dc3d7e72b38f431d8aa0c4bf95ccee6bf
# 5    36d9cbb4c6bc0c1a6911436d2da0d09ec625e43e6552f575d4acc9cf487c4686
# 6    bfce39c89d6549f2bb94d8064d3ce69dc3d7e72b38f431d8aa0c4bf95ccee6bf
# 7    fd6563a4e0f6f4273580e5fedbd8dda64990447aea5a33cbb5e894a3867ca44d
# 8    ad6390295640af1ed0e45ffc58a53b2d9074b0eea694b16210addd44d7c81f83
# ...

# %%
count(sessions)
# Out:
#   n
# 1 1535

# %%
# Provide summary statistics for the sessions data set by finding the number of session occurrences by email.
sessions_email <- sessions |>
    group_by(hashedEmail) |>
    count()
sessions_email

sessions_email_max <- sessions_email |>
    ungroup() |>
    summarize(n = max(n))
sessions_email_max
# Out:
#     hashedEmail                                                      n
# 1   0088b5e134c3f0498a18c7ea6b8d77b4b0ff1636fc93355ccc95b45423367832   2
# 2   060aca80f8cfbf1c91553a72f4d5ec8034764b05ab59fe8e1cf0eee9a7b67967   1
# 3   0ce7bfa910d47fc91f21a7b3acd8f33bde6db57912ce0290fa0437ce0b97f387   1
# 4   0d4d71be33e2bc7266ee4983002bd930f69d304288a8663529c875f40f1750f3  13
# 5   0d70dd9cac34d646c810b1846fe6a85b9e288a76f5dcab9c1ff1a0e7ca200b3a   2
# 6   11006065e9412650e99eea4a4aaaf0399bc338006f85e80cc82d18b49f0e2aa4   1
# 7   119f01b9877fc5ea0073d05602a353b91c4b48e4cf02f42bb8d661b46a34b760   1
# 8   18936844e06b6c7871dce06384e2d142dd86756941641ef39cf40a9967ea14e3  41
# 9   1a2b92f18f36b0b59b41d648d10a9b8b20a2adff550ddbcb8cec2f47d4d881d0   1
# 10  1d2371d8a35c8831034b25bda8764539ab7db0f63938696917c447128a2540dd   1
# 11  200db0417ee70863c7e2a0f214c737476fb86de5869d0b907a077d726357e687   1
# 12  20ae3f8b5323674fe6e537bc91928841cfc2a00c1b36522fd25370bb6fa89d36   2
# ...

# %%
# Provide summmary statistics by determining if any sessions started or ended at the same time and the number that did.
sessions_start <- sessions |>
    group_by(start_time) |>
    count()
sessions_start

sessions_start_max <- sessions_start |>
    ungroup() |>
    summarize(n = max(n))
sessions_start_max

sessions_end <- sessions |>
    group_by(end_time) |>
    count()
sessions_end

sessions_end_max <- sessions_end |>
    ungroup() |>
    summarize(n = max(n))
sessions_end_max
# Out:
#      start_time       n
# 1    01/05/2024 00:58 1
# 2    01/05/2024 02:28 1
# 3    01/05/2024 02:41 1
# 4    01/05/2024 03:29 1
# 5    01/05/2024 04:54 1
# 6    01/05/2024 05:46 1
# 7    01/05/2024 18:16 1
# 8    01/05/2024 20:34 1
# 9    01/05/2024 22:42 1
# 10   01/05/2024 23:46 1
# 11   01/06/2024 00:27 1
# 12   01/06/2024 02:22 1
# 13   01/06/2024 02:29 1
# 14   01/06/2024 05:42 1
# 15   01/06/2024 05:45 1
# 16   01/06/2024 06:22 1
# 17   01/06/2024 06:35 1
# 18   01/06/2024 14:44 1
# 19   01/06/2024 17:01 1
# 20   01/06/2024 17:29 1
# 21   01/06/2024 17:32 1
# 22   01/06/2024 18:11 1
# 23   01/06/2024 18:27 1
# 24   01/06/2024 18:28 1
# 25   01/06/2024 20:01 1
# 26   01/06/2024 22:19 1
# 27   01/06/2024 23:51 1
# 28   01/07/2024 00:10 1
# 29   01/07/2024 00:55 1
# 30   01/07/2024 01:43 1
# ⋮    ⋮                ⋮
# 1475 30/08/2024 03:40 1
# 1476 30/08/2024 04:05 1
# 1477 30/08/2024 05:04 1
# 1478 30/08/2024 05:08 1
# 1479 30/08/2024 15:25 1
# 1480 30/08/2024 15:48 1
# ...

# %%
# Calculate the average start and end time for sessions using the original times.
avg_original_start <- sessions |>
    summarize(original_start_time = mean(original_start_time))
avg_original_start

avg_original_end <- sessions |>
    summarize(original_end_time = mean(original_end_time, na.rm = TRUE))
avg_original_end
# Out:
#   original_start_time
# 1 1.719201e+12
#   original_end_time
# 1 1.719196e+12

# %%
# The same data can be gathered by using summary to find statistics on the sessions data set.
summary(sessions)
# Out:
#  hashedEmail         start_time          end_time         original_start_time
#  Length:1535        Length:1535        Length:1535        Min.   :1.712e+12
#  Class :character   Class :character   Class :character   1st Qu.:1.716e+12
#  Mode  :character   Mode  :character   Mode  :character   Median :1.719e+12
#                                                           Mean   :1.719e+12
#                                                           3rd Qu.:1.722e+12
#                                                           Max.   :1.727e+12
#
#  original_end_time
#  Min.   :1.712e+12
#  1st Qu.:1.716e+12
#  Median :1.719e+12
#  Mean   :1.719e+12
#  3rd Qu.:1.722e+12
#  Max.   :1.727e+12
#  NA's   :2

# %% [markdown]
# ### Sessions Data Set
# The sessions data set includes a list of individual play sessions by each player with data on the session. In the data set, there are 5 variables, as both character and double data types, and 1535 observations.
# - hashedEmail(chr): an encrypted version of an email address used to protect the user's personal information, used in coordination with the players data set
# - start_time(chr): the time the Minecraft session began in day, month, year, time format
# - end_time(chr): the time the Minecraft session ended in day, month, year, time format
# - original_start_time(dbl): the start time of the session as a single number
# - original_end_time(dbl): the end time of the session as a single number
#
# **Hashed Email**
#
# By using group_by and count, I am able to determine the number of sessions each player participated in. Out of the 196 total players, 125 are present in the sessions data set, where the most sessions played by a single player(identified by their hashedEmail) is 310 sessions.
#
# **Session Start and End Time**
#
# From calculating summary statistics on the start and end time of sessions, I found that there are only 1504 observations for start time and 1490 for end time. This indicates that several sessions started or ended at the same time, the max being 3, or in some situations the time was listed as NA.
#
# **Original Start and End Time**
#
# The average original start and end times are shown in the table below.
# | Average Original Start Time | Average Original End Time |
# | --------------------------- | ------------------------- |
# | 1.72e+12                    | 1.72e+12                  |
#
# After performing summary statistics on the sessions data set, I noticed that the number of hashedEmails identified is less than the total players. With this, I assume that 71 players did not participate in a session, however, it is unclear the exact reason given only the data. Additionally, I am unsure as to how the original start and end times were converted and whether they are accurate.

# %% [markdown]
# # Questions
# #### Broad Question: Which "kinds" of players are most likely to contribute large amounts of data(sessions)?
# #### Specific Question: Can hours played, age, and number of sessions predict player experience?
# In investigating my specific question, I chose hours played as a predictor since the time spend on the game could correlate to how advanced of a player an individual is. Next, age provides insight on the development of an individual and the potential time a player could have had to learn the game and build skills. Lastly, the number of sessions suggest how frequently a player logs into Minecraft showing their commitment to the game. Thus, by using these three predictors to classify a player's experience, I would be able to determine the type of player which contributes video game data. To apply classification, I would need to use the group by and summarize function to calculate the number of sessions by hashedEmail, merging the sessions and players data set with bind_cols.

# %% [markdown]
# # Exploratory Data Analysis and Visualization
# ### Wrangle into Tidy Data

# %%
# Wrangle data into tidy format. 
# Since the sessions dataset includes 4 columns with information on time, I can use pivot longer to combine the columns in one row.
# First, I need to convert original_start_time and original_end_time to a character data type to match start_time and end_time.
sessions <- sessions |>
    mutate(
        original_start_time = as.character(original_start_time), 
        original_end_time = as.character(original_end_time))

sessions_tidy <- pivot_longer(sessions,
                              cols = start_time:original_end_time,
                              names_to = "time_type", 
                              values_to = "time")
sessions_tidy
# Out:
#      hashedEmail
# 1    bfce39c89d6549f2bb94d8064d3ce69dc3d7e72b38f431d8aa0c4bf95ccee6bf
# 2    bfce39c89d6549f2bb94d8064d3ce69dc3d7e72b38f431d8aa0c4bf95ccee6bf
# 3    bfce39c89d6549f2bb94d8064d3ce69dc3d7e72b38f431d8aa0c4bf95ccee6bf
# 4    bfce39c89d6549f2bb94d8064d3ce69dc3d7e72b38f431d8aa0c4bf95ccee6bf
# 5    36d9cbb4c6bc0c1a6911436d2da0d09ec625e43e6552f575d4acc9cf487c4686
# 6    36d9cbb4c6bc0c1a6911436d2da0d09ec625e43e6552f575d4acc9cf487c4686
# 7    36d9cbb4c6bc0c1a6911436d2da0d09ec625e43e6552f575d4acc9cf487c4686
# 8    36d9cbb4c6bc0c1a6911436d2da0d09ec625e43e6552f575d4acc9cf487c4686
# 9    f8f5477f5a2e53616ae37421b1c660b971192bd8ff77e3398304c7ae42581fdc
# 10   f8f5477f5a2e53616ae37421b1c660b971192bd8ff77e3398304c7ae42581fdc
# 11   f8f5477f5a2e53616ae37421b1c660b971192bd8ff77e3398304c7ae42581fdc
# 12   f8f5477f5a2e53616ae37421b1c660b971192bd8ff77e3398304c7ae42581fdc
# 13   bfce39c89d6549f2bb94d8064d3ce69dc3d7e72b38f431d8aa0c4bf95ccee6bf
# ...

# %% [markdown]
# ### Mean Values for Players Dataset
# | Average Played Hours | Average Age |
# | -------------------- | ----------- |
# | 5.85                 | 21.14       |

# %% [markdown]
# ### Exploratory Visualizations

# %%
# Create a bar graph comparing the distribution of experience levels using the players_experience table from earlier.
experience_plot <- ggplot(players_experience, aes(x = experience, y = n)) +
    geom_bar(stat = "identity", fill = "lightpink") +
    labs(x = "Experience Level", y = "Number of Players", title = "Distribution of Player Experience Levels") +
    theme(text = element_text(size = 15)) 
experience_plot
# Out:
# plot without title

# %%
# Create a bar graph comparing the distribution of genders using the players_gender table from earlier.
gender_plot <- ggplot(players_gender, aes(x = gender, y = n)) +
    geom_bar(stat = "identity", fill = "lightblue") +
    labs(x = "Gender", y = "Number of Players", title = "Distribution of Player Genders") +
    theme(text = element_text(size = 15)) +
    theme(axis.text.x = element_text(angle = 45, hjust = 1))
gender_plot
# Out:
# plot without title

# %%
# Plot the relationship between age and hours played, colored by experience level.
age_hours_plot <- ggplot(players, aes(x = Age, y = played_hours, color = experience)) +
    geom_point() +
    labs(x = "Age (Years)", y = "Hours Played", title = "Relationship Between Age and Hours Played", color = "Experience Level") +
    theme(text = element_text(size = 13))
age_hours_plot
# It looks like there are only a few points since the range of hours played is so great. 
# If you look closely, you can see clusters of points at common ages of Minecraft players.
# Out:
# Warning message:
# “Removed 2 rows containing missing values or values outside the scale range
# (`geom_point()`).”
# plot without title

# %% [markdown]
# # Methods and Plan
